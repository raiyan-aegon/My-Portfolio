# %% [markdown]
# ## Script to scrap data from Twitter

# %%
import requests
# For saving access tokens and for file management when creating and adding to the dataset
import os
# For dealing with json responses we receive from the API
import json
# For displaying the data after
import pandas as pd
# For saving the response data in CSV format
import csv

# %%
os.environ['TOKEN'] = 'AAAAAAAAAAAAAAAAAAAAAEF8WAEAAAAAvOEdxa20BDBFApkhzqgGVr96wCs%3Dy9PN8cLhX8pMgGJLDZmLxstnlZHBqpOExSw7LCE4Pp12Sb5BZc'

# %%
## to return the bearer token
def auth():
    return os.getenv('TOKEN')

## create headers to pass token 
def create_headers(bearer_token):
    headers = {"Authorization": "Bearer {}".format(bearer_token)}
    return headers

# %%
## create url 
def create_url(keyword, start_date, end_date, max_results = 5000):
    
    ## get all search data
    search_url = "https://api.twitter.com/2/tweets/search/recent" 
    
    query_params = {'query': keyword,
                    'start_time': start_date,
                    'end_time': end_date,
                    'max_results': max_results}
    
    return (search_url, query_params)

# %%
## connect to end point
def connect_to_endpoint(url, headers, params, next_token = None):
    params['next_token'] = next_token   #params object received from create_url function
    response = requests.request("GET", url, headers = headers, params = params)
    print("Endpoint Response Code: " + str(response.status_code))
    if response.status_code != 200:
        raise Exception(response.status_code, response.text)
    return response.json()

# %%
## create url to fetch data

#Inputs for the request
bearer_token = auth()
headers = create_headers(bearer_token)
keyword = "mtn gh lang:en"
start_time = "2021-11-18T04:49:31.000Z"
end_time = "2021-11-24T04:39:31.000Z"
max_results = 100

url = create_url(keyword, start_time,end_time, max_results)

## store data to json object
json_response = connect_to_endpoint(url[0], headers, url[1])

print(json.dumps(json_response, indent=4, sort_keys=True))
# Out:
# Endpoint Response Code: 200
# {
#     "data": [
#         {
#             "id": "1463267912630812679",
#             "text": "@philip_one_ Y'ello! Thank you for contacting MTN and sincere apologies for the delay in response. Kindly share GPS cordinates or select new request using below link to make request. \u00a0Thank you. *Susan #WeDey4U  \nhttps://t.co/6qykH4Yhls"
#         },
#         {
#             "id": "1463146384778043393",
#             "text": "RT @espioj: MTN Ghana is #hiring! COORDINATOR (Applications &amp; Partnerships) #jobtube #ghana #vacancy #jobseekers #jobsearch #employment @MT\u2026"
#         },
#         {
#             "id": "1463142300721295371",
#             "text": "Hello MTN GH,\nHaving network challenges since yesterday. Very poor network. Can't make a call or browse the internet. I reside in Akosombo"
#         },
#         {
#             "id": "1463141853486792718",
# ...
